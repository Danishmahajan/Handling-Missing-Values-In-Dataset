# %% [markdown]
# # Adding Missing Category

# %% [markdown]
# ###### Suppose if you have more frequent categories, we just replace NAN with a new category

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('loan.csv',usecols=['BsmtQual','FireplaceQu', 'GarageType', 'SalePrice'])
df
# Out:
#      BsmtQual FireplaceQu GarageType  SalePrice
# 0          Gd         NaN     Attchd     208500
# 1          Gd          TA     Attchd     181500
# 2          Gd          TA     Attchd     223500
# 3          TA          Gd     Detchd     140000
# 4          Gd          TA     Attchd     250000
# ...       ...         ...        ...        ...
# 1455       Gd          TA     Attchd     175000
# 1456       Gd          TA     Attchd     210000
# 1457       TA          Gd     Attchd     266500
# 1458       TA         NaN     Attchd     142125
# 1459       TA         NaN     Attchd     147500
#
# [1460 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# BsmtQual        37
# FireplaceQu    690
# GarageType      81
# SalePrice        0
# dtype: int64

# %% [markdown]
# ####  Plots Before Adding the Missing category in NAN values

# %%
df['BsmtQual'].value_counts().plot.bar(color='orchid')
plt.title("Before Adding Missing in BsmtQual ")
# Out:
# Text(0.5, 1.0, 'Before Adding Missing in BsmtQual ')

# %%
df['FireplaceQu'].value_counts().plot.bar(color='lightseagreen')
plt.title("Before Adding Missing in FireplaceQu ")
# Out:
# Text(0.5, 1.0, 'Before Adding Missing in FireplaceQu ')

# %%
df['GarageType'].value_counts().plot.bar(color='firebrick')
plt.title("Before Adding Missing in Garagetype ")
# Out:
# Text(0.5, 1.0, 'Before Adding Missing in Garagetype ')

# %%
def impute_nan(df,var):
    df[var+'_Missing']=np.where(df[var].isnull(),'Missing',df[var]) # or You can make change in original feature

# %%
for feature in ['BsmtQual','FireplaceQu', 'GarageType']:
    impute_nan(df,feature)

# %%
df.head(50)
# Out:
#    BsmtQual FireplaceQu GarageType  SalePrice BsmtQual_Missing  \
# 0        Gd         NaN     Attchd     208500               Gd
# 1        Gd          TA     Attchd     181500               Gd
# 2        Gd          TA     Attchd     223500               Gd
# 3        TA          Gd     Detchd     140000               TA
# 4        Gd          TA     Attchd     250000               Gd
# 5        Gd         NaN     Attchd     143000               Gd
# 6        Ex          Gd     Attchd     307000               Ex
# 7        Gd          TA     Attchd     200000               Gd
# 8        TA          TA     Detchd     129900               TA
# 9        TA          TA     Attchd     118000               TA
# 10       TA         NaN     Detchd     129500               TA
# 11       Ex          Gd    BuiltIn     345000               Ex
# 12       TA         NaN     Detchd     144000               TA
# 13       Gd          Gd     Attchd     279500               Gd
# ...

# %%
df.drop(['BsmtQual','FireplaceQu', 'GarageType'],axis=1,inplace=True)

# %%
df
# Out:
#       SalePrice BsmtQual_Missing FireplaceQu_Missing GarageType_Missing
# 0        208500               Gd             Missing             Attchd
# 1        181500               Gd                  TA             Attchd
# 2        223500               Gd                  TA             Attchd
# 3        140000               TA                  Gd             Detchd
# 4        250000               Gd                  TA             Attchd
# ...         ...              ...                 ...                ...
# 1455     175000               Gd                  TA             Attchd
# 1456     210000               Gd                  TA             Attchd
# 1457     266500               TA                  Gd             Attchd
# 1458     142125               TA             Missing             Attchd
# 1459     147500               TA             Missing             Attchd
#
# [1460 rows x 4 columns]

# %% [markdown]
# ####  Plots After Adding the Missing category in NAN values

# %%
df['BsmtQual_Missing'].value_counts().plot.bar(color='orchid')
plt.title("After Adding Missing in BsmtQual ")
# Out:
# Text(0.5, 1.0, 'After Adding Missing in BsmtQual ')

# %%
df['FireplaceQu_Missing'].value_counts().plot.bar(color='lightseagreen')
plt.title("After Adding Missing in FireplaceQu ")
# Out:
# Text(0.5, 1.0, 'After Adding Missing in FireplaceQu ')

# %%
df['GarageType_Missing'].value_counts().plot.bar(color='firebrick')
plt.title("After Adding Missing in Garagetype ")
# Out:
# Text(0.5, 1.0, 'After Adding Missing in Garagetype ')
